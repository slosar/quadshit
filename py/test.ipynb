# %%
import quadshit as qs
reload(qs)
import matplotlib.pyplot as plt
import scipy.linalg as la
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Zeroth test -- sum over Fourier modes

# %%
D=qs.QuadShit()
k,Pk,Pke=D.getPkIdiotic(Ng=1000)
plt.plot(k,Pk)

# %%
plt.errorbar(k[:10],Pk[:10],yerr=Pke[:10])
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ## Basic OQE with one binning, but possibly masking

# %%
reload(qs)
mask=np.ones(1024)
mask[900:]=0.0
mask[100:]=0.0
D=qs.QuadShit(mask=mask)
# derivs
Sp,xil=D.getSponez()
FD,SD=D.getOQE(Sp,500)
# Out:
# Creating Sp
# Getting FD
# quadshit.py:50: RuntimeWarning: invalid value encountered in divide
#   xip=(np.sin(kup*2*np.pi*np.arange(N)/N)-np.sin(kdown*2*np.pi*np.arange(N)/N))/(2*np.pi*np.arange(N)/N)
# Getting SD
# 0.119232231254

# %%
plt.plot(xil[2])
print xil[2][0:2]
#plt.plot(xil[4])
# Out:
# [ 0.00976562  0.00975748]

# %%
ks,Pk,err=D.getPkfromD(FD,SD)
plt.errorbar(ks+0.5,Pk,yerr=err)
plt.xlim(0,5)
plt.plot([0,6],[1,1])
# Out:
# chi2= 1.03834336685 chi2 diag= 0.685266094737

# %%
plt.imshow(la.inv(SD),interpolation='nearest')
print la.eig(SD)[0]
plt.colorbar()
# Out:
# [  2.41037896e+04+0.j   2.25874578e+02+0.j   1.07343934e+02+0.j
#    4.22745767e-02+0.j   3.26799711e+01+0.j]

# %% [markdown]
# ## Z evolution

# %%
reload(qs)
D=qs.QuadShit(A2=2.0)
# derivs
Sp,xil,wl,wh=D.getSp3Alt()
plt.plot(wl)
plt.plot(wh)
Sp1,xil=D.getSponez()
for S in [Sp1[2], Sp[2], Sp[7],Sp[12],Sp[2]+Sp[7]+Sp[12]]:
    plt.figure()
    plt.imshow(S,interpolation='nearest')
# Out:
# Creating Sp
# Creating Sp

# %%
FD,SD=D.getOQE(Sp,500)
# Out:
# Getting FD
# Getting SD
# 0.335741108027

# %%
# is it pos def?
la.eig(SD)[0]
plt.imshow(SD,interpolation='nearest')

# %%
ks,Pk,err=D.getPkfromD(FD,SD)
plt.errorbar(ks+0.5,Pk,yerr=err)
plt.plot([0,5],[1,1],'r')
plt.plot([5,10],[((D.A2+1)/2)**2,((D.A2+1)/2)**2],'r')
plt.plot([10,15],[D.A2**2,D.A2**2],'r')
# Out:
# chi2= 74024.0108221 chi2 diag= 35747.7278358
