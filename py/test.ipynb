# %%
import quadshit as qs
reload(qs)
import matplotlib.pyplot as plt
import scipy.linalg as la
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Zeroth test -- sum over Fourier modes

# %%
D=qs.QuadShit()
k,Pk,Pke=D.getPkIdiotic(Ng=1000)
plt.plot(k,Pk)

# %%
plt.errorbar(k[:10],Pk[:10],yerr=Pke[:10])
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ## Basic OQE with one binning, but possibly masking

# %%
reload(qs)
mask=np.ones(1024)
#mask[0:100]=0.0
#mask[700:]=0.0
D=qs.QuadShit(mask=mask)
# derivs
Sp,xil=D.getSponez()
FD,SD=D.getOQE(Sp,500)
# Out:
# Creating Sp
# Getting FD
# Getting SD
# 1.0

# %%
ks,Pk,err=D.getPkfromD(FD,SD)
plt.errorbar(ks+0.5,Pk,yerr=err)
plt.plot([0,6],[1,1])
# Out:
# chi2= 5.31192698887 chi2 diag= 5.31192698887

# %%
plt.imshow(SD,interpolation='nearest')

# %% [markdown]
# ## Z evolution

# %% [markdown]
# # reload(qs)
# D=qs.QuadShit(A2=2.0)
# # derivs
# Sp,xil=D.getSp3()
# Sp1,xil=D.getSponez()
# for S in [Sp1[0], Sp[0], Sp[5],Sp[10],Sp[0]+Sp[5]+Sp[10]]:
#     plt.figure()
#     plt.imshow(S,interpolation='nearest')

# %%
FD,SD=D.getOQE(Sp,500)
# Out:
# Getting FD
# Getting SD
# 0.0180655868251

# %%
# is it pos def?
la.eig(SD)[0]
plt.imshow(SD,interpolation='nearest')

# %%
ks,Pk,err=D.getPkfromD(FD,SD)
plt.errorbar(ks,Pk,yerr=err)
plt.plot([0,4],[1,1],'r')
plt.plot([5,9],[D.A2**2/2,D.A2**2/2],'r')
plt.plot([10,14],[D.A2**2,D.A2**2],'r')
# Out:
# chi2= 1653.10656114 chi2 diag= 1096.77915936
