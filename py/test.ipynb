# %%
import quadshit as qs
reload(qs)
import matplotlib.pyplot as plt
import scipy.linalg as la
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Zeroth test -- sum over Fourier modes

# %%
D=qs.QuadShit()
k,Pk,Pke=D.getPkIdiotic(Ng=1000)
plt.plot(k,Pk)

# %%
plt.errorbar(k[:10],Pk[:10],yerr=Pke[:10])
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ## Basic OQE with one binning, but possibly masking

# %%
reload(qs)
mask=np.ones(1024)
mask[400:]=0.0
#mask[700:]=0.0
D=qs.QuadShit(mask=mask)
# derivs
Sp,xil=D.getSponez()
FD,SD=D.getOQE(Sp,500)
# Out:
# Creating Sp
# Getting FD
# Getting SD
# 0.158679751158

# %%
ks,Pk,err=D.getPkfromD(FD,SD)
plt.errorbar(ks+0.5,Pk,yerr=err)
print err
plt.plot([0,6],[1,1])
# Out:
# chi2= 128.619772195 chi2 diag= 303.658130766
# [ 0.15407404  0.22175137  0.25459703  0.24621921  0.17618266]

# %%
plt.imshow(SD,interpolation='nearest')
print SD
# Out:
# [[ 81.39115936  46.39880425   8.14314432   1.53141589   4.14058319]
#  [ 46.39880425  79.33987558  44.95465233   6.19186697   2.05548545]
#  [  8.14314432  44.95465233  77.38859823  45.47872188   5.21316033]
#  [  1.53141589   6.19186697  45.47872188  76.40989159  45.5351125 ]
#  [  4.14058319   2.05548545   5.21316033  45.5351125   76.33664795]]

# %% [markdown]
# ## Z evolution

# %%
# reload(qs)
D=qs.QuadShit(A2=1.0)
# derivs
Sp,xil=D.getSp3()
Sp1,xil=D.getSponez()
for S in [Sp1[0], Sp[0], Sp[5],Sp[10],Sp[0]+Sp[5]+Sp[10]]:
    plt.figure()
    plt.imshow(S,interpolation='nearest')
# Out:
# Creating Sp
# Creating Sp

# %%
FD,SD=D.getOQE(Sp,500)
# Out:
# Getting FD
# Getting SD
# 0.0881537718448

# %%
# is it pos def?
la.eig(SD)[0]
plt.imshow(SD,interpolation='nearest')

# %%
ks,Pk,err=D.getPkfromD(FD,SD)
plt.errorbar(ks+0.5,Pk,yerr=err)
plt.plot([0,5],[1,1],'r')
plt.plot([5,10],[(D.A2**2+1)/2,(D.A2**2+1)/2],'r')
plt.plot([10,15],[D.A2**2,D.A2**2],'r')
# Out:
# chi2= 132.465193157 chi2 diag= 186.132587181
